# %%
import os
from ftplib import FTP
import pandas as pd
import datetime as dt

def download_spires_data(
    year: int,
    months: list[str],
    product: str = "NRT",         # or "HIST"
    tile: str = "h09v05",
    destination_base: str = "~/data/spires"
):
    """
    Download SPIRES data from the CU FTP server for a given year and list of months.
    
    Parameters:
        year (int): The year of data to download (e.g., 2023)
        months (list[str]): List of 2-digit month strings to download (e.g., ["04", "05"])
        product (str): Either "NRT" or "HIST"
        tile (str): Tile identifier, e.g., "h09v05"
        destination_base (str): Base path to store data (e.g., "~/data/spires")
    """
    
    # Validate input
    assert product in ["NRT", "HIST"], "Product must be 'NRT' or 'HIST'"
    for m in months:
        assert len(m) == 2 and m.isdigit(), f"Month {m} must be a 2-digit string"

    # FTP connection info
    host_name = "dtn.rc.colorado.edu"
    ftp_user = "anonymous"
    ftp_pwd = "pwd"
    base_path = "/shares/snow-today/spires"
    sub_path = f"SPIRES_{product}_V01/{tile}"
    remote_path = f"{base_path}/{sub_path}/{year}"

    # Create date range and filter
    start_date = dt.datetime(year, 1, 1)
    end_date = dt.datetime(year, 12, 31)
    all_dates = pd.date_range(start=start_date, end=end_date, freq="D")
    filtered_dates = all_dates[all_dates.strftime("%m").isin(months)]

    # Format filenames
    file_template = f"SPIRES_{product}_{tile}_MOD09GA061_{{date}}_V1.0.nc"
    file_names = [file_template.format(date=d.strftime("%Y%m%d")) for d in filtered_dates]

    # Create local output directory
    output_dir = os.path.expanduser(f"{destination_base}/{year}")
    os.makedirs(output_dir, exist_ok=True)

    # Connect to FTP and download files
    ftp = FTP(host_name)
    ftp.login(user=ftp_user, passwd=ftp_pwd)
    ftp.cwd(remote_path)

    for fname in file_names:
        local_path = os.path.join(output_dir, fname)
        if not os.path.exists(local_path):  # Avoid redownloading
            try:
                with open(local_path, 'wb') as f:
                    ftp.retrbinary(f"RETR {fname}", f.write)
                print(f"Downloaded: {fname}")
            except Exception as e:
                print(f"❌ Could not download {fname}: {e}")
        else:
            print(f"✔️ Already exists: {fname}")

    ftp.quit()
    print(f"All downloads complete. Check {output_dir} for files.")
    return

# %%
import rioxarray as rxr
import xarray as xr
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
test_download_spires_data = download_spires_data(
    year=2024,
    months=["04", "05"],
    product="HIST",
    tile="h08v05",
    destination_base="/storage/dlhogan/spires/tuolumne")
# Out:
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240401_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240402_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240403_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240404_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240405_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240406_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240407_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240408_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240409_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240410_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240411_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240412_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240413_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240414_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240415_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240416_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240417_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240418_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240419_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240420_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240421_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240422_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240423_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240424_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240425_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240426_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240427_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240428_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240429_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240430_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240501_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240502_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240503_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240504_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240505_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240506_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240507_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240508_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240509_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240510_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240511_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240512_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240513_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240514_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240515_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240516_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240517_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240518_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240519_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240520_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240521_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240522_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240523_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240524_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240525_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240526_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240527_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240528_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240529_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240530_V1.0.nc
# Downloaded: SPIRES_HIST_h08v05_MOD09GA061_20240531_V1.0.nc
# All downloads complete. Check /storage/dlhogan/spires/tuolumne/2024 for files.

# %%
# open the basin of interest
basin_file = ("/storage/dlhogan/ess_project_data/domain_Tuolumne_River/shapefiles/catchment/Toulumne_HRUs_GRUs.shp")
basin_gdf = gpd.read_file(basin_file)

# lets check one of these files
test_file = os.path.join(os.path.expanduser("/storage/dlhogan/spires/tuolumne/2025"), "SPIRES_NRT_h08v05_MOD09GA061_20250518_V1.0.nc")
ds = xr.open_dataset(test_file)

# write crs
ds = ds.rio.write_crs(ds.crs.attrs['crs_wkt'])

# check to make sure the crs matches between basin_gdf and ds 
if basin_gdf.crs != ds.rio.crs:
    print("CRS mismatch! Basin GDF CRS:", basin_gdf.crs, "Dataset CRS:", ds.rio.crs)
    # reproject ds to match basin_gdf
    ds = ds.rio.reproject(basin_gdf.crs)
    print("Reprojected dataset CRS:", ds.rio.crs)
    # check that they match again
    if basin_gdf.crs != ds.rio.crs:
        raise ValueError("CRS still does not match after reprojection!")
# Out:
# CRS mismatch! Basin GDF CRS: EPSG:4326 Dataset CRS: PROJCS["MODIS Sinusoidal",GEOGCS["User with datum World Geodetic Survey 1984",DATUM["unnamed",SPHEROID["unnamed",6371007.181,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Sinusoidal"],PARAMETER["longitude_of_center",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Reprojected dataset CRS: EPSG:4326

# %%
# now we can clip the dataset to the basin
ds_clipped = ds.rio.clip(basin_gdf.geometry, basin_gdf.crs)

# let's plot the snow_fraction variable
ds_clipped['snow_fraction'].plot(cmap='viridis')

# %% [markdown]
# Next, I want to download the dem and reproject to match. then we can create a time series as different elevation bands. we could also try adding in the NLCD dataset to see if filtering on that makes a difference.
